# %%
from __future__ import print_function
__author__= 'mal'

import numpy as np
import pylab as pl
from scipy.optimize import curve_fit, minimize

    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Chisq Distribution

# %%
distribution =['chisq']

# %%
mymean=100

# %%
df=mymean

# %%
md = {}
allmeans= []
md['chisq'] = np.random.chisquare(df, size=100)
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# #### Fig 1: Chi sq distribution: df=100, N=100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 98.62, standard deviation: 14.62

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['chisq'] = {}

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)   

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
        allmeans.append(md['chisq']['means'][nn])

# %% [markdown]
# #### Fig 2: The fig above illustrates that for randomly generated samples, the larger the number of variables, the more they converge along the mean of the distribution.

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Fig 3: Mean of all samples

# %% [markdown]
# ### Normal Distribution

# %%
distributions =['lnorm']

# %%
mymean=100

# %%
df=mymean

# %%
md ={}

# %%
md['lnorm']= np.random.normal(df, size=100)

# %%
pl.hist(md['lnorm'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# #### Figure 1: Normal Distribution: df = 100, N=100

# %%
print("lnorm mean: %.2f, standard deviation: %.2f"%(md['lnorm'].mean(),md['lnorm'].std()))
# Out:
# lnorm mean: 100.06, standard deviation: 0.88

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['lnorm'] = {}

# %%
for n in mysize:
    md['lnorm'][n] = np.random.normal(df, size = n)

# %%
md['lnorm'] = {} 

for n in mysize:
    md['lnorm'][n] = np.random.normal(df, size = 100)   

md['lnorm']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lnorm']:
    if not type(nn) == str:
        md['lnorm']['means'][nn] = md['lnorm'][nn].mean()
        
        axchisq_mu_n.plot(nn, md['lnorm']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Normal Distribution', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
        allmeans.append(md['lnorm']['means'][nn])

# %% [markdown]
# #### Fig 2: The fig above illustrates that for randomly generated samples, the larger the number of variables, the more they converge along the mean of the distribution.

# %%
allmeans = list(md['lnorm']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Figure 3: Mean of all samples

# %% [markdown]
# ### Poisson Distribution

# %%
distributions = ['pois']

# %%
mymean=100

# %%
df= mymean

# %%
md = {}

# %%
md['pois']= np.random.chisquare(df, size=100)

# %%
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# #### Figure 1: Poisson distribution: df = 100, N=100

# %%
print("pois mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(),md['pois'].std()))
# Out:
# pois mean: 99.58, standard deviation: 13.70

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['pois'] = {} 

for n in mysize:
    md['pois'][n] = np.random.poisson(df, size = n)
    
md['pois']['means'] = {}
axchisq_mu_n = plt.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Poisson Distribution', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
        allmeans.append(md['pois']['means'][nn])

# %% [markdown]
# #### Fig 2: The fig above illustrates that for randomly generated samples, the larger the number of variables, the more they converge along the mean of the distribution.

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Fig 3: Poisson distribution sample mean

# %% [markdown]
# ### Binomial Distribution

# %%
distributions = ['binom']

# %%
mymean=100

# %%
df = mymean

# %%
md = {}

# %%
md['binom'] = np.random.binomial(df, 0.2, size=100)
pl.hist(md['binom'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# #### Fig 1: Binomial distribution: df = 100, N=100

# %%
print("binom mean: %.2f, standard deviation: %.2f"%(md['binom'].mean(),md['binom'].std()))
# Out:
# binom mean: 19.91, standard deviation: 3.74

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['binom'] = {} 

for n in mysize:
    md['binom'][n] = np.random.binomial(df, 0.2, size = n)

md['binom']['means'] = {}
axbinom_mu_n = plt.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binom']:
    if not type(nn) == str:
        md['binom']['means'][nn] = md['binom'][nn].mean()
        axbinom_mu_n.plot(nn, md['binom']['means'][nn], 'o')
        axbinom_mu_n.set_xlabel('sample size', fontsize=18)
        axbinom_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinom_mu_n.set_title('Binomial', fontsize=18)
        axbinom_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
        allmeans.append(md['binom']['means'][nn])

# %% [markdown]
# #### Figure 2: The fig above illustrates that for randomly generated samples, the larger the number of variables, the more they converge along the mean of the distribution.

# %%
allmeans = list(md['binom']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Fig 3: Binomial distribution sample mean

# %%
distributions = ['stan_t']

# %%
mymean = 100

# %%
df = mymean

# %%
md = {}

# %%
md['stan_t'] = np.random.standard_t(df, size=100)
pl.hist(md['stan_t'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')

# %% [markdown]
# #### Fig 1: Standard_t distribution: df = 100, N=100¶

# %%
print("stan_t mean: %.2f, standard deviation: %.2f"%(md['stan_t'].mean(),md['stan_t'].std()))
# Out:
# stan_t mean: -0.08, standard deviation: 1.02

# %%
mysize = (2000 / (np.array(range(1, 100)))).astype(int)
print (mysize, mysize.shape)
# Out:
# [2000 1000  666  500  400  333  285  250  222  200  181  166  153  142  133
#   125  117  111  105  100   95   90   86   83   80   76   74   71   68   66
#    64   62   60   58   57   55   54   52   51   50   48   47   46   45   44
#    43   42   41   40   40   39   38   37   37   36   35   35   34   33   33
#    32   32   31   31   30   30   29   29   28   28   28   27   27   27   26
#    26   25   25   25   25   24   24   24   23   23   23   22   22   22   22
#    21   21   21   21   21   20   20   20   20] (99,)

# %%
md['stan_t'] = {} 

for n in mysize:
    md['stan_t'][n] = np.random.standard_t(df, size = n)

md['stan_t']['means'] = {}
axstan_t_mu_n = plt.figure(figsize=(10,6)).add_subplot(111)

for nn in md['stan_t']:
    if not type(nn) == str:
        md['stan_t']['means'][nn] = md['stan_t'][nn].mean()
        axstan_t_mu_n.plot(nn, md['stan_t']['means'][nn], 'o')
        axstan_t_mu_n.set_xlabel('sample size', fontsize=18)
        axstan_t_mu_n.set_ylabel('sample mean', fontsize=18)
        axstan_t_mu_n.set_title('standard_t', fontsize=18)
        axstan_t_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
        allmeans.append(md['stan_t']['means'][nn])

# %% [markdown]
# #### Fig 2: The fig above illustrates that for randomly generated samples, the larger the number of variables, the more they converge along the mean of the distribution

# %%
allmeans = list(md['stan_t']['means'].values())

plt.figure(figsize=(10, 10))
plt.hist(allmeans,bins=30)
plt.xlabel('sample mean', fontsize = 18)
plt.ylabel('N', fontsize = 18)

# %% [markdown]
# #### Fig 3: Standard_t distribution sample mean

# %% [markdown]
# ### Histogram of all sample means

# %%
pl.figure(figsize = (10, 10))
pl.hist(allmeans, bins=30)
pl.xlabel('Histogram of all sample means', fontsize = 16)
pl.ylabel('N', fontsize = 16)
